# %%
#Importing necessary libraries

import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

#setting some constants

BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS = 3
EPOCHS = 10

# Load the dataset with the help of directory
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/potatoes",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)

# Get the class names(early_blight,healthy,late_blight)
class_names = dataset.class_names
print(class_names)

# Print the shape of an image batch and labels batch
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())

# Visualize some sample images from the dataset
plt.figure(figsize=(10, 10))   #setting the size of image
for images, labels in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# Split the dataset into train, validation, and test sets
train_size = int(len(dataset) * 0.8)
val_size = int(len(dataset) * 0.1)
test_size = len(dataset) - train_size - val_size

train_dataset = dataset.take(train_size)
test_dataset = dataset.skip(train_size)
val_dataset = test_dataset.skip(val_size)
test_dataset = test_dataset.take(test_size)

print("Length of train_dataset:", len(train_dataset))
print("Length of val_dataset:", len(val_dataset))
print("Length of test_dataset:", len(test_dataset))

# Configure the datasets for performance
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.cache().prefetch(buffer_size=AUTOTUNE)

# Define the model
model = models.Sequential([
    layers.Rescaling(1./255, input_shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS)),
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(len(class_names), activation='softmax')
])

model.summary()

# Compile and train the model
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)
#ready to training
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS
)
# Out:
# Found 789 files belonging to 4 classes.
# ['.ipynb_checkpoints', 'early_blight', 'healthy', 'late_blight']
# (32, 256, 256, 3)
# [1 3 1 1 1 3 3 3 3 3 3 1 2 2 3 3 1 1 3 3 3 3 1 3 3 3 2 3 1 1 3 3]
# Length of train_dataset: 20
# Length of val_dataset: 3
# Length of test_dataset: 3
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_21 (Conv2D)          (None, 254, 254, 32)      896
#
#  max_pooling2d_21 (MaxPoolin  (None, 127, 127, 32)     0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 125, 125, 64)      18496
#
#  max_pooling2d_22 (MaxPoolin  (None, 62, 62, 64)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 60, 60, 128)       73856
#
#  max_pooling2d_23 (MaxPoolin  (None, 30, 30, 128)      0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 115200)            0
#
#  dense_8 (Dense)             (None, 128)               14745728
#
#  dense_9 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 14,839,492
# Trainable params: 14,839,492
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 20/20 [==============================] - 134s 6s/step - loss: 1.8011 - accuracy: 0.4203 - val_loss: 0.8800 - val_accuracy: 0.6941
# Epoch 2/10
# 20/20 [==============================] - 114s 6s/step - loss: 0.6779 - accuracy: 0.7203 - val_loss: 0.4870 - val_accuracy: 0.7882
# Epoch 3/10
# 20/20 [==============================] - 122s 6s/step - loss: 0.3891 - accuracy: 0.8406 - val_loss: 0.2418 - val_accuracy: 0.9059
# Epoch 4/10
# 20/20 [==============================] - 112s 6s/step - loss: 0.2567 - accuracy: 0.9016 - val_loss: 0.1421 - val_accuracy: 0.9647
# Epoch 5/10
# 20/20 [==============================] - 104s 5s/step - loss: 0.1877 - accuracy: 0.9281 - val_loss: 0.1561 - val_accuracy: 0.9294
# Epoch 6/10
# 20/20 [==============================] - 105s 5s/step - loss: 0.0775 - accuracy: 0.9734 - val_loss: 0.1223 - val_accuracy: 0.9765
# Epoch 7/10
# 20/20 [==============================] - 104s 5s/step - loss: 0.0614 - accuracy: 0.9812 - val_loss: 0.0634 - val_accuracy: 0.9765
# Epoch 8/10
# 20/20 [==============================] - 105s 5s/step - loss: 0.0360 - accuracy: 0.9937 - val_loss: 0.0605 - val_accuracy: 0.9765
# Epoch 9/10
# 20/20 [==============================] - 103s 5s/step - loss: 0.0269 - accuracy: 0.9937 - val_loss: 0.1265 - val_accuracy: 0.9765
# Epoch 10/10
# 20/20 [==============================] - 104s 5s/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 0.0253 - val_accuracy: 0.9882

# %%
#to calucalate the accuracy
scores = model.evaluate(test_ds)
# Out:
# 3/3 [==============================] - 4s 1s/step - loss: 0.2249 - accuracy: 0.9583

# %%
scores
# Out:
# [0.22485339641571045, 0.9583333134651184]

# %%
history

# %%
history.params   #paramneter ussed for it
# Out:
# {'verbose': 1, 'epochs': 10, 'steps': 20}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
type(history.history['loss'])
# Out:
# list

# %%
len(history.history['loss'])
# Out:
# 10

# %%
history.history['loss'][:5] # showing loss for first 5 epochs
# Out:
# [1.8011295795440674,
#  0.6778532862663269,
#  0.389062762260437,
#  0.2566995918750763,
#  0.18770429491996765]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: late_blight
# 1/1 [==============================] - 2s 2s/step
# predicted label: late_blight

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 71ms/step
